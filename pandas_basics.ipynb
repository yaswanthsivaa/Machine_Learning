# %%
# %pip install -U pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Out:
# c:\Users\91628\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# **Series**

# %%
s = pd.Series([10,20,30,40,50], name="Marks") # name = Column name

# %%
print(type(s))
# Out:
# <class 'pandas.Series'>

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Marks, dtype: int64

# %%
print(s[0])
print(s.mean())
# Out:
# 10
# 30.0

# %%
# Data Frame
data = {
  "Name":['Alice', 'Bob', 'Charle', "David", "Elvin", "Faf", "Grok", "Hazel", "Immanuel"],
  "Age":[24,27,22,32,37,47,27,67,57],
  "Score":[85,91,78,88,89,99,47,68,54]
}
df = pd.DataFrame(data)

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
print(df)
# Out:
#        Name  Age  Score
# 0     Alice   24     85
# 1       Bob   27     91
# 2    Charle   22     78
# 3     David   32     88
# 4     Elvin   37     89
# 5       Faf   47     99
# 6      Grok   27     47
# 7     Hazel   67     68
# 8  Immanuel   57     54

# %%
df.head() #df.tail()
# Out:
#      Name  Age  Score
# 0   Alice   24     85
# 1     Bob   27     91
# 2  Charle   22     78
# 3   David   32     88
# 4   Elvin   37     89

# %%
# save the dataframe to a csv file
df.to_csv("data_sample.csv", index=False)

# %% [markdown]
# **Read data from a csv file**

# %%
ds = pd.read_csv("data_sample.csv")

# %%
ds.shape
# Out:
# (9, 3)

# %%
ds.columns
# Out:
# Index(['Name', 'Age', 'Score'], dtype='str')

# %%
ds.head() # first 5 rows in the dataframe
# Out:
#      Name  Age  Score
# 0   Alice   24     85
# 1     Bob   27     91
# 2  Charle   22     78
# 3   David   32     88
# 4   Elvin   37     89

# %%
ds.tail()
# Out:
#        Name  Age  Score
# 4     Elvin   37     89
# 5       Faf   47     99
# 6      Grok   27     47
# 7     Hazel   67     68
# 8  Immanuel   57     54

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    9 non-null      str
#  1   Age     9 non-null      int64
#  2   Score   9 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 392.0 bytes

# %%
print("Shape:",ds.shape)
print("\nColumns:",ds.columns)
print("\nData types:\n", ds.dtypes)
# Out:
# Shape: (9, 3)
#
# Columns: Index(['Name', 'Age', 'Score'], dtype='str')
#
# Data types:
#  Name       str
# Age      int64
# Score    int64
# dtype: object

# %%
print(type(df["Name"]))
# Out:
# <class 'pandas.Series'>

# %%
print(df[["Name", "Age"]])
# Out:
#        Name  Age
# 0     Alice   24
# 1       Bob   27
# 2    Charle   22
# 3     David   32
# 4     Elvin   37
# 5       Faf   47
# 6      Grok   27
# 7     Hazel   67
# 8  Immanuel   57

# %%
print(type(df[["Name", "Age"]]))
# Out:
# <class 'pandas.DataFrame'>

# %%
# Row Selection
print(df.iloc[0]) # by index
# Out:
# Name     Alice
# Age         24
# Score       85
# Name: 0, dtype: object

# %%
print(df.loc[0])
# Out:
# Name     Alice
# Age         24
# Score       85
# Name: 0, dtype: object

# %%
print(df.loc[1])
# Out:
# Name     Bob
# Age       27
# Score     91
# Name: 1, dtype: object

# %%
data = {
  "Name":["Raghava", "Ramana", "Rama", "Krishna"],
  "Score":[88,92,95,78]
}

sample_data_2 = pd.DataFrame(data, index=["a", "b", "c", "d"])

# %%
sample_data_2.head()
# Out:
#       Name  Score
# a  Raghava     88
# b   Ramana     92
# c     Rama     95
# d  Krishna     78

# %%
sample_data_2.iloc[1] # to print based on the position
# Out:
# Name     Ramana
# Score        92
# Name: b, dtype: object

# %%
sample_data_2.loc["b"] # when you have the custom label then use loc if you wanna print with labels
# Out:
# Name     Ramana
# Score        92
# Name: b, dtype: object

# %% [markdown]
# *Filtering rows with Condition*

# %%
# filter the rows whose marks is less than or equal to 50

print(df[df["Score"] <= 85])
# Out:
#        Name  Age  Score
# 0     Alice   24     85
# 2    Charle   22     78
# 6      Grok   27     47
# 7     Hazel   67     68
# 8  Immanuel   57     54

# %%
# Creating the new Columns in the Dataset

df["Passed"] = df["Score"] >= 60

# %%
df
# Out:
#        Name  Age  Score  Passed
# 0     Alice   24     85    True
# 1       Bob   27     91    True
# 2    Charle   22     78    True
# 3     David   32     88    True
# 4     Elvin   37     89    True
# 5       Faf   47     99    True
# 6      Grok   27     47   False
# 7     Hazel   67     68    True
# 8  Immanuel   57     54   False

# %%
df['Score_Percentage'] = (df['Score'] / 100) * 100

# %%
df
# Out:
#        Name  Age  Score  Passed  Score_Percentage
# 0     Alice   24     85    True              85.0
# 1       Bob   27     91    True              91.0
# 2    Charle   22     78    True              78.0
# 3     David   32     88    True              88.0
# 4     Elvin   37     89    True              89.0
# 5       Faf   47     99    True              99.0
# 6      Grok   27     47   False              47.0
# 7     Hazel   67     68    True              68.0
# 8  Immanuel   57     54   False              54.0

# %%
# To add completely new Column
df['city'] = ['Delhi', 'Mumbai', 'Hyderabad', 'Bangalore', 'Chennai', 'Kolkata',None, None, None]

# %%
df
# Out:
#        Name  Age  Score  Passed  Score_Percentage       city
# 0     Alice   24     85    True              85.0      Delhi
# 1       Bob   27     91    True              91.0     Mumbai
# 2    Charle   22     78    True              78.0  Hyderabad
# 3     David   32     88    True              88.0  Bangalore
# 4     Elvin   37     89    True              89.0    Chennai
# 5       Faf   47     99    True              99.0    Kolkata
# 6      Grok   27     47   False              47.0        NaN
# 7     Hazel   67     68    True              68.0        NaN
# 8  Immanuel   57     54   False              54.0        NaN

# %% [markdown]
# **Descriptive Statistics**

# %%
print("Average Score:", df['Score'].mean())
print("Maximum Score:", df['Score'].max())
print("Minimum Score:", df['Score'].min())
# Out:
# Average Score: 77.66666666666667
# Maximum Score: 99
# Minimum Score: 47

# %%
df.describe()
# Out:
#              Age      Score  Score_Percentage
# count   9.000000   9.000000          9.000000
# mean   37.777778  77.666667         77.666667
# std    15.864881  17.734148         17.734148
# min    22.000000  47.000000         47.000000
# 25%    27.000000  68.000000         68.000000
# 50%    32.000000  85.000000         85.000000
# 75%    47.000000  89.000000         89.000000
# max    67.000000  99.000000         99.000000

# %% [markdown]
# *To Update the Value*

# %%
sample_data_3 = pd.DataFrame(data)

# %%
df
# Out:
#        Name  Age  Score  Passed  Score_Percentage       city
# 0     Alice   24     85    True              85.0      Delhi
# 1       Bob   27     91    True              91.0     Mumbai
# 2    Charle   22     78    True              78.0  Hyderabad
# 3     David   32     88    True              88.0  Bangalore
# 4     Elvin   37     89    True              89.0    Chennai
# 5       Faf   47     99    True              99.0    Kolkata
# 6      Grok   27     47   False              47.0        NaN
# 7     Hazel   67     68    True              68.0        NaN
# 8  Immanuel   57     54   False              54.0        NaN

# %%
df.loc[df['Name'] == 'Elvin', 'Name'] = 'Erick'

# %%
df
# Out:
#        Name  Age  Score  Passed  Score_Percentage       city
# 0     Alice   24     85    True              85.0      Delhi
# 1       Bob   27     91    True              91.0     Mumbai
# 2    Charle   22     78    True              78.0  Hyderabad
# 3     David   32     88    True              88.0  Bangalore
# 4     Erick   37     89    True              89.0    Chennai
# 5       Faf   47     99    True              99.0    Kolkata
# 6      Grok   27     47   False              47.0        NaN
# 7     Hazel   67     68    True              68.0        NaN
# 8  Immanuel   57     54   False              54.0        NaN

# %%
df.loc[df['Score'] > 90, 'Score'] = None
df
# Out:
#        Name  Age  Score  Passed  Score_Percentage       city
# 0     Alice   24   85.0    True              85.0      Delhi
# 1       Bob   27    NaN    True              91.0     Mumbai
# 2    Charle   22   78.0    True              78.0  Hyderabad
# 3     David   32   88.0    True              88.0  Bangalore
# 4     Erick   37   89.0    True              89.0    Chennai
# 5       Faf   47    NaN    True              99.0    Kolkata
# 6      Grok   27    NaN   False              47.0        NaN
# 7     Hazel   67   68.0    True              68.0        NaN
# 8  Immanuel   57    NaN   False              54.0        NaN

# %% [markdown]
# *Handling Missing Data*

# %%
df.loc[df['Score'] == None, 'Score'] = 0
df.loc[df['Name'] == 'Erick', 'Name'] = None
df
# Out:
#        Name  Age  Score  Passed  Score_Percentage       city
# 0     Alice   24   85.0    True              85.0      Delhi
# 1       Bob   27    NaN    True              91.0     Mumbai
# 2    Charle   22   78.0    True              78.0  Hyderabad
# 3     David   32   88.0    True              88.0  Bangalore
# 4       NaN   37   89.0    True              89.0    Chennai
# 5       Faf   47    NaN    True              99.0    Kolkata
# 6      Grok   27    NaN   False              47.0        NaN
# 7     Hazel   67   68.0    True              68.0        NaN
# 8  Immanuel   57    NaN   False              54.0        NaN

# %%
df.head()
# Out:
#      Name  Age  Score  Passed  Score_Percentage       city
# 0   Alice   24   85.0    True              85.0      Delhi
# 1     Bob   27    NaN    True              91.0     Mumbai
# 2  Charle   22   78.0    True              78.0  Hyderabad
# 3   David   32   88.0    True              88.0  Bangalore
# 4     NaN   37   89.0    True              89.0    Chennai

# %%
df.dropna(subset=['Name'], inplace=True, ignore_index=True) #ignore_index = True :-- it resets the index

# %%
df
# Out:
#        Name  Age  Score  Passed  Score_Percentage       city
# 0     Alice   24   85.0    True              85.0      Delhi
# 1       Bob   27    NaN    True              91.0     Mumbai
# 2    Charle   22   78.0    True              78.0  Hyderabad
# 3     David   32   88.0    True              88.0  Bangalore
# 4       Faf   47    NaN    True              99.0    Kolkata
# 5      Grok   27    NaN   False              47.0        NaN
# 6     Hazel   67   68.0    True              68.0        NaN
# 7  Immanuel   57    NaN   False              54.0        NaN

# %%
df['Score'] = df['Score'].fillna(df['Score'].mean())

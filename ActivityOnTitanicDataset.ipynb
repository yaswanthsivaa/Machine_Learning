# %%
# Load the dataset and explore it step by step.

# Load the Titanic dataset using Pandas ---

# Inspect the shape, columns, and basic information ---

# Check for missing values and handle them appropriately ---

# Find how many passengers survived and did not survive ---

# Analyze survival based on gender ---

# Analyze survival based on passenger class ---

# Find the average age and average fare ---

# Create simple visualizations to support your findings

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.isnull().sum()
# here age column has less missing values so take avg and drop Cabin becoz it has high missing vals

df['Age'].fillna(df['Age'].mean())
# df.drop('Cabin', axis=1, inplace=True)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby('Sex')['Pclass'].value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: count, dtype: int64

# %%
df.groupby('Passenger')

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='Survived', data=df)
plt.title("Visual Survival Graph")
plt.xlabel('Not Survival vs Survival')
plt.ylabel('Frequency')
plt.show()

# %%
df.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.show()

# %%
sns.histplot(df['Age'])
plt.show()

# %%
# Out:
# 245
